# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.color import rgb2gray, rgb2hsv
from skimage.morphology import area_opening
from skimage.exposure import histogram
from skimage.filters import threshold_otsu
from PIL import Image
import os
import matplotlib.pyplot as plt
import cv2
import pickle
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8528\2972962603.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from skimage.io import imread, imshow
#       4 from skimage.color import rgb2gray, rgb2hsv
#       5 from skimage.morphology import area_opening
#
# ModuleNotFoundError: No module named 'skimage'

# %%
path = 'Dataset'

# %%
#Menyimpan gambar setelah proses thresholding ke dalam folder Threshold
save_path = 'Threshold/'
def masked_image(image, mask):
    r = image[:,:,0] * mask
    g = image[:,:,1] * mask
    b = image[:,:,2] * mask
    return np.dstack([r,g,b])

for filename in os.listdir(path):
    if not os.path.isdir(save_path + filename):
        os.mkdir(save_path + filename)
    for index, imagename in enumerate(os.listdir(os.path.join(path, filename))):
        image = imread(os.path.join(path, filename, imagename))
        gray = rgb2gray(image)
        thresh = threshold_otsu(gray)
        masking  = gray < thresh
        filtered = masked_image(image, masking)
        image = Image.fromarray(filtered)
        image = image.resize((778, 437))
        image = np.asarray(image)
        
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(f'{save_path}/{filename}/{filename}_{index + 1}.jpg', image)
# Out:
# 15.536716217726612
# 7.110268265948205

# %%
path_threshold = 'Threshold'

# %%
#Menyimpan Gambar setelah di ubah RGB to HSV ke dalam Folder HSV
save_hsv = 'HSV/'
for filename in os.listdir(path_threshold):
    if not os.path.isdir(save_hsv + filename):
        os.mkdir(save_hsv + filename)
    for imagename in os.listdir(os.path.join(path_threshold, filename)):
        image = imread(os.path.join(path_threshold, filename, imagename))
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        print(image.mean())
        break
#         cv2.imwrite(f'{save_hsv}/{filename}/{imagename}', image)
# Out:
# 24.571361761954904
# 15.600500216675588

# %%
path_hsv = 'HSV/'

# %%
#Mencari mean darI Gambar untuk menentukan nilai mean HSV, kemudian menyimpannya ke dalam bentuk array
data_hsv = {}
for filename in os.listdir(path_hsv):
    for imagename in os.listdir(os.path.join(path_hsv, filename)):
        image = cv2.imread(os.path.join(path_hsv, filename, imagename))
        
        h,s,v = cv2.split(image)
        hmean = h.mean()
        smean = s.mean()
        vmean = v.mean()
        data_hsv[f'{imagename}'] = (hmean, smean, vmean, filename)

# %%
data_hsv
# Out:
# {'Babi_1.jpg': (24.68409581571006,
#   27.508729771225873,
#   22.43625031618949,
#   'Babi'),
#  'Babi_10.jpg': (18.921464413240546,
#   17.771002335390282,
#   12.466436853282193,
#   'Babi'),
#  'Babi_11.jpg': (23.174798374050695,
#   15.590944921261464,
#   18.98742595283335,
#   'Babi'),
#  'Babi_12.jpg': (19.50947391951433,
#   21.777343772978888,
#   15.74514538833952,
#   'Babi'),
#  'Babi_13.jpg': (23.828154688722478,
#   26.4891142576459,
#   21.89973410669851,
#   'Babi'),
#  'Babi_14.jpg': (20.56037601548299,
#   17.525642232327215,
#   14.33068420464372,
#   'Babi'),
#  'Babi_15.jpg': (15.99750577964975,
#   17.1752778055567,
#   11.476913755272276,
#   'Babi'),
#   15.313283488143629,
#   'Sapi'),
#  'Sapi_14.jpg': (18.297671080573906,
#   22.912708170336426,
#   16.374171289406036,
#   'Sapi'),
#  'Sapi_15.jpg': (20.99460566023307,
#   23.90599612925238,
#   19.346223079773875,
#   'Sapi'),
#  'Sapi_16.jpg': (24.52011847546664,
#   28.356638214514714,
#   25.362144323589796,
#   'Sapi'),
#  'Sapi_17.jpg': (16.00905625525757,
#   19.64827669374621,
#   15.004644308883307,
#   'Sapi'),
#  'Sapi_18.jpg': (21.911337525662823,
#   27.48095215685352,
#   20.06350261481355,
#   'Sapi'),
#  'Sapi_19.jpg': (24.145205979069726,
#   28.336269728753535,
#   23.857611784014637,
#   'Sapi'),
#  'Sapi_2.jpg': (14.463719094315648,
#   18.266019777284946,
#   10.061199578806185,
#   'Sapi'),
#  'Sapi_20.jpg': (20.729985940597555,
#   25.639511626949346,
#   17.952865706234963,
#   'Sapi'),
#  'Sapi_21.jpg': (20.45695116857753,
#   24.73892454395181,
#   19.068752830998925,
#   'Sapi'),
#  'Sapi_22.jpg': (23.93302077144353,
#   24.19077256122311,
#   24.501785367632785,
#   'Sapi'),
#  'Sapi_23.jpg': (27.184048754948734,
#   30.38822480925685,
#   26.802153618090156,
#   'Sapi'),
#  'Sapi_24.jpg': (18.197537545663646,
#   20.154053402198915,
#   17.549334384357003,
#   'Sapi'),
#  'Sapi_25.jpg': (18.015809474507773,
#   21.583259310677498,
#   14.40648144335355,
#   'Sapi'),
#  'Sapi_26.jpg': (21.0442782938121,
#   24.50048825539875,
#   19.965010323954516,
#   'Sapi'),
#  'Sapi_27.jpg': (24.565143858864776,
#   28.759063608501528,
#   22.58178277929091,
#   'Sapi'),
#  'Sapi_28.jpg': (24.731665421517356,
#   30.72705346690746,
#   24.152926885224687,
#   'Sapi'),
#  'Sapi_29.jpg': (23.117507779732108,
#   25.731891901431236,
#   23.96109251557417,
#   'Sapi'),
#  'Sapi_3.jpg': (12.817936620919685,
#   15.653232780173301,
#   8.421782073379491,
#   'Sapi'),
#  'Sapi_30.jpg': (20.13793215014736,
#   23.812280505667882,
#   18.44854788138335,
#   'Sapi'),
#  'Sapi_4.jpg': (16.63073773625973,
#   20.116493032066025,
#   13.459951292112029,
#   'Sapi'),
#  'Sapi_5.jpg': (26.412828763537323,
#   29.455671704128992,
#   22.360417781908666,
#   'Sapi'),
#  'Sapi_6.jpg': (23.84634367297477,
#   32.67753672210032,
#   18.451283288135393,
#   'Sapi'),
#  'Sapi_7.jpg': (15.273820098474642,
#   16.84902613637032,
#   10.138146864870906,
#   'Sapi'),
#  'Sapi_8.jpg': (16.251919196672805,
#   19.597904031342466,
#   11.359320677910267,
#   'Sapi'),
#  'Sapi_9.jpg': (21.114192937356243,
#   27.008885659997766,
#   18.06879400916508,
#   'Sapi')}

# %%
#Membuat file dengan ekstensi .pickle
file = open('Enkoding/hsv_value.pkl', 'wb')
pickle = pickle.dump(data_hsv, file)
file.close()
