# %%
import cv2
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import skimage.io
import skimage.color
import skimage.filters

# %%
image = skimage.io.imread("babi.JPG")

# %%
# convert the image to grayscale
gray_image = skimage.color.rgb2gray(image)

# blur the image to denoise
blurred_image = skimage.filters.gaussian(gray_image, sigma=1.0)

# show the histogram of the blurred image
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))
fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Graylevel histogram")
plt.xlabel("gray value")
plt.ylabel("pixel count")
plt.xlim(0, 1.0)
plt.show()

# %%
# perform automatic thresholding
t = skimage.filters.threshold_otsu(blurred_image)
print("Found automatic threshold t = {}.".format(t))
# Out:
# Found automatic threshold t = 0.5933190134515409.

# %%
# create a binary mask with the threshold found by Otsu's method
binary_mask = blurred_image > t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1044\2217489475.py in <module>
#       1 # create a binary mask with the threshold found by Otsu's method
# ----> 2 binary_mask = blurred_image > t
#       3
#       4 fig, ax = plt.subplots()
#       5 plt.imshow(binary_mask, cmap='gray')
#
# NameError: name 't' is not defined

# %%
# apply the binary mask to select the foreground
selection = np.zeros_like(image)
selection[binary_mask] = image[binary_mask]

fig, ax = plt.subplots()
plt.imshow(selection)
plt.show()
